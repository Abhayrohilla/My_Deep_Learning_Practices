# %%
from transformers import pipeline
question_answerer = pipeline('question-answering')
question_answerer({'question': 'What is the name of the repository ?','context': 'Pipeline has been included in the huggingface/transformers repository'})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\ABHAYR~1\AppData\Local\Temp/ipykernel_20308/504208727.py in <module>
# ----> 1 from transformers import pipeline
#       2 question_answerer = pipeline('question-answering')
#       3 question_answerer({'question': 'What is the name of the repository ?','context': 'Pipeline has been included in the huggingface/transformers repository'})
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\__init__.py in __getattr__(self, name)
#    3024             if name == "__version__":
#    3025                 return __version__
# -> 3026             return super().__getattr__(name)
#    3027
#    3028     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\file_utils.py in __getattr__(self, name)
#    1887             value = self._get_module(name)
#    1888         elif name in self._class_to_module.keys():
# -> 1889             module = self._get_module(self._class_to_module[name])
#    1890             value = getattr(module, name)
#    1891         else:
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\__init__.py in _get_module(self, module_name)
#    3018
#    3019         def _get_module(self, module_name: str):
# -> 3020             return importlib.import_module("." + module_name, self.__name__)
#    3021
#    3022         def __getattr__(self, name: str):
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_backward_compatible(spec)
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\pipelines\__init__.py in <module>
#      24 from ..file_utils import is_tf_available, is_torch_available
#      25 from ..models.auto.configuration_auto import AutoConfig
# ---> 26 from ..models.auto.feature_extraction_auto import FEATURE_EXTRACTOR_MAPPING, AutoFeatureExtractor
#      27 from ..models.auto.tokenization_auto import TOKENIZER_MAPPING, AutoTokenizer
#      28 from ..tokenization_utils import PreTrainedTokenizer
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_backward_compatible(spec)
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\models\auto\feature_extraction_auto.py in <module>
#      18 from collections import OrderedDict
#      19
# ---> 20 from transformers import DeiTFeatureExtractor, Speech2TextFeatureExtractor, ViTFeatureExtractor
#      21
#      22 from ... import DeiTConfig, PretrainedConfig, Speech2TextConfig, ViTConfig, Wav2Vec2Config
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\__init__.py in __getattr__(self, name)
#    3024             if name == "__version__":
#    3025                 return __version__
# -> 3026             return super().__getattr__(name)
#    3027
#    3028     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\file_utils.py in __getattr__(self, name)
#    1888         elif name in self._class_to_module.keys():
#    1889             module = self._get_module(self._class_to_module[name])
# -> 1890             value = getattr(module, name)
#    1891         else:
#    1892             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\file_utils.py in __getattr__(self, name)
#    1887             value = self._get_module(name)
#    1888         elif name in self._class_to_module.keys():
# -> 1889             module = self._get_module(self._class_to_module[name])
#    1890             value = getattr(module, name)
#    1891         else:
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\models\speech_to_text\__init__.py in _get_module(self, module_name)
#      80
#      81         def _get_module(self, module_name: str):
# ---> 82             return importlib.import_module("." + module_name, self.__name__)
#      83
#      84     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_backward_compatible(spec)
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\models\speech_to_text\feature_extraction_speech_to_text.py in <module>
#      21 import numpy as np
#      22 import torch
# ---> 23 import torchaudio.compliance.kaldi as ta_kaldi
#      24
#      25 from ...feature_extraction_sequence_utils import SequenceFeatureExtractor
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\__init__.py in <module>
# ----> 1 from . import extension  # noqa: F401
#       2 from torchaudio._internal import module_utils as _mod_utils  # noqa: F401
#       3 from torchaudio import (
#       4     compliance,
#       5     datasets,
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\extension\__init__.py in <module>
#       3 )
#       4
# ----> 5 _init_extension()
#       6
#       7 del _init_extension
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\extension\extension.py in _init_extension()
#       9     ext = 'torchaudio._torchaudio'
#      10     if _mod_utils.is_module_available(ext):
# ---> 11         _init_script_module(ext)
#      12         import torchaudio._torchaudio  # noqa
#      13     else:
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\extension\extension.py in _init_script_module(module)
#      17 def _init_script_module(module):
#      18     path = importlib.util.find_spec(module).origin
# ---> 19     torch.classes.load_library(path)
#      20     torch.ops.load_library(path)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torch\_classes.py in load_library(self, path)
#      44             path (str): A path to a shared library to load.
#      45         """
# ---> 46         torch.ops.load_library(path)
#      47
#      48 # The classes "namespace"
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torch\_ops.py in load_library(self, path)
#     102             # static (global) initialization code in order to register custom
#     103             # operators with the JIT.
# --> 104             ctypes.CDLL(path)
#     105         self.loaded_libraries.add(path)
#     106
#
# ~\anaconda3\envs\Demo_GPU\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371
#     372         if handle is None:
# --> 373             self._handle = _dlopen(self._name, mode)
#     374         else:
#     375             self._handle = handle
#
# OSError: [WinError 127] The specified procedure could not be found

# %%
from transformers import pipeline

nlp = pipeline("question-answering")

context = r"""
Extractive Question Answering is the task of extracting an answer from a text given a question. An example of a
question answering dataset is the SQuAD dataset, which is entirely based on that task. If you would like to fine-tune
a model on a SQuAD task, you may leverage the `run_squad.py`.
"""

print(nlp(question="What is extractive question answering?", context=context))
print(nlp(question="What is a good example of a question answering dataset?", context=context))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\ABHAYR~1\AppData\Local\Temp/ipykernel_20308/782868554.py in <module>
# ----> 1 from transformers import pipeline
#       2
#       3 nlp = pipeline("question-answering")
#       4
#       5 context = r"""
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\__init__.py in __getattr__(self, name)
#    3024             if name == "__version__":
#    3025                 return __version__
# -> 3026             return super().__getattr__(name)
#    3027
#    3028     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\file_utils.py in __getattr__(self, name)
#    1887             value = self._get_module(name)
#    1888         elif name in self._class_to_module.keys():
# -> 1889             module = self._get_module(self._class_to_module[name])
#    1890             value = getattr(module, name)
#    1891         else:
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\__init__.py in _get_module(self, module_name)
#    3018
#    3019         def _get_module(self, module_name: str):
# -> 3020             return importlib.import_module("." + module_name, self.__name__)
#    3021
#    3022         def __getattr__(self, name: str):
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_backward_compatible(spec)
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\pipelines\__init__.py in <module>
#      24 from ..file_utils import is_tf_available, is_torch_available
#      25 from ..models.auto.configuration_auto import AutoConfig
# ---> 26 from ..models.auto.feature_extraction_auto import FEATURE_EXTRACTOR_MAPPING, AutoFeatureExtractor
#      27 from ..models.auto.tokenization_auto import TOKENIZER_MAPPING, AutoTokenizer
#      28 from ..tokenization_utils import PreTrainedTokenizer
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_backward_compatible(spec)
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\models\auto\feature_extraction_auto.py in <module>
#      18 from collections import OrderedDict
#      19
# ---> 20 from transformers import DeiTFeatureExtractor, Speech2TextFeatureExtractor, ViTFeatureExtractor
#      21
#      22 from ... import DeiTConfig, PretrainedConfig, Speech2TextConfig, ViTConfig, Wav2Vec2Config
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\__init__.py in __getattr__(self, name)
#    3024             if name == "__version__":
#    3025                 return __version__
# -> 3026             return super().__getattr__(name)
#    3027
#    3028     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\file_utils.py in __getattr__(self, name)
#    1888         elif name in self._class_to_module.keys():
#    1889             module = self._get_module(self._class_to_module[name])
# -> 1890             value = getattr(module, name)
#    1891         else:
#    1892             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\file_utils.py in __getattr__(self, name)
#    1887             value = self._get_module(name)
#    1888         elif name in self._class_to_module.keys():
# -> 1889             module = self._get_module(self._class_to_module[name])
#    1890             value = getattr(module, name)
#    1891         else:
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\models\speech_to_text\__init__.py in _get_module(self, module_name)
#      80
#      81         def _get_module(self, module_name: str):
# ---> 82             return importlib.import_module("." + module_name, self.__name__)
#      83
#      84     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\envs\Demo_GPU\lib\importlib\_bootstrap.py in _load_backward_compatible(spec)
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\transformers-4.8.1-py3.8.egg\transformers\models\speech_to_text\feature_extraction_speech_to_text.py in <module>
#      21 import numpy as np
#      22 import torch
# ---> 23 import torchaudio.compliance.kaldi as ta_kaldi
#      24
#      25 from ...feature_extraction_sequence_utils import SequenceFeatureExtractor
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\__init__.py in <module>
# ----> 1 from . import extension  # noqa: F401
#       2 from torchaudio._internal import module_utils as _mod_utils  # noqa: F401
#       3 from torchaudio import (
#       4     compliance,
#       5     datasets,
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\extension\__init__.py in <module>
#       3 )
#       4
# ----> 5 _init_extension()
#       6
#       7 del _init_extension
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\extension\extension.py in _init_extension()
#       9     ext = 'torchaudio._torchaudio'
#      10     if _mod_utils.is_module_available(ext):
# ---> 11         _init_script_module(ext)
#      12         import torchaudio._torchaudio  # noqa
#      13     else:
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torchaudio\extension\extension.py in _init_script_module(module)
#      17 def _init_script_module(module):
#      18     path = importlib.util.find_spec(module).origin
# ---> 19     torch.classes.load_library(path)
#      20     torch.ops.load_library(path)
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torch\_classes.py in load_library(self, path)
#      44             path (str): A path to a shared library to load.
#      45         """
# ---> 46         torch.ops.load_library(path)
#      47
#      48 # The classes "namespace"
#
# ~\anaconda3\envs\Demo_GPU\lib\site-packages\torch\_ops.py in load_library(self, path)
#     102             # static (global) initialization code in order to register custom
#     103             # operators with the JIT.
# --> 104             ctypes.CDLL(path)
#     105         self.loaded_libraries.add(path)
#     106
#
# ~\anaconda3\envs\Demo_GPU\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371
#     372         if handle is None:
# --> 373             self._handle = _dlopen(self._name, mode)
#     374         else:
#     375             self._handle = handle
#
# OSError: [WinError 127] The specified procedure could not be found
